# %% [markdown]
# <a href="https://colab.research.google.com/github/jollyjunojuunoh-crypto/cs1-python-emerald-ko/blob/main/cs1_fa1_eme_ko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Grade 7!")
# Out:
# Hello Grade 7!
